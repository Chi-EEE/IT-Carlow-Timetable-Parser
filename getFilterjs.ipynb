# %%
import requests

# %%
res = requests.get("http://timetable.itcarlow.ie/js/filter.js")

# %%
filterJS = res.text

# %%
import re

# %%
filterJS
# Out:
# '// Generated Automatically on 30 Sep 2022 17:09:20\r\n// Copyright Scientia Ltd 2022\r\n// Scientia does not accept any warranty with regard to the content or usage of this file\r\n// Institution Start Date: 01/08/22\r\n\r\nvar roomarray = new Array(226);\r\nvar studsetarray = new Array(527);\r\nvar staffarray = new Array(565);\r\nvar roombydeptarray = new Array(226);\r\nvar modulearray = new Array(2814);\r\nvar progarray = new Array(399);\r\n\r\nfunction PopulateFilter(strZoneOrDept, cbxFilter) {\r\n    var deptarray = new Array(13);\r\n    for (var i=0; i<deptarray.length; i++) {\r\n        deptarray[i] = new Array(1);\r\n    }\r\n    deptarray[0] [0] = "Department of Sports, Media & Marketing";\r\n    deptarray[0] [1] = "SMM";\r\n    deptarray[1] [0] = "Institute of Technology Carlow";\r\n    deptarray[1] [1] = "ITC";\r\n    deptarray[2] [0] = "Department of Lifelong Learning - Carlow";\r\n    deptarray[2] [1] = "NGT";\r\n    deptarray[3] [0] = "Wexford Campus";\r\n    deptarray[3] [1] = "WEX";\r\n    deptarray[4] [0] = "Wexford Campus Lifelong Learning";\r\n    deptarray[4] [1] = "WNT";\r\n    deptarray[5] [0] = "Department of Lifelong Learning - Wicklow";\r\n    deptarray[5] [1] = "WW";\r\n    deptarray[6] [0] = "Department of Business";\r\n    deptarray[6] [1] = "BC";\r\n    deptarray[7] [0] = "Department of Management Studies";\r\n    deptarray[7] [1] = "MS";\r\n    deptarray[8] [0] = "Department of the Built Environment & Extended Campus";\r\n    deptarray[8] [1] = "BE";\r\n    deptarray[9] [0] = "Department of Humanities";\r\n    deptarray[9] [1] = "HM";\r\n    deptarray[10] [0] = "Department of Aerospace, Mechanical & Electronic Engineering";\r\n    deptarray[10] [1] = "EMA";\r\n    deptarray[11] [0] = "Department of Computing and Networking";\r\n    deptarray[11] [1] = "CAN";\r\n    deptarray[12] [0] = "Department of Science and Health";\r\n    deptarray[12] [1] = "DSH";\r\n    deptarray.sort();\r\n    var zonearray = new Array(12);\r\n    for (var i=0; i<zonearray.length; i++) {\r\n        zonearray[i] = new Array(1);\r\n    }\r\n    zonearray[0] [0] = "Haughton Building";\r\n    zonearray[0] [1] = "Haughton Building";\r\n    zonearray[1] [0] = "Portarlington";\r\n    zonearray[1] [1] = "Port\'ton";\r\n    zonearray[2] [0] = "CIM";\r\n    zonearray[2] [1] = "CIM";\r\n    zonearray[3] [0] = "LRC";\r\n    zonearray[3] [1] = "LRC";\r\n    zonearray[4] [0] = "Nore Building";\r\n    zonearray[4] [1] = "Nore Building";\r\n    zonearray[5] [0] = "Burrin Building";\r\n    zonearray[5] [1] = "Burrin Building";\r\n    zonearray[6] [0] = "Killeshin Centre";\r\n    zonearray[6] [1] = "Killeshin Centre";\r\n    zonearray[7] [0] = "Barrow Centre";\r\n    zonearray[7] [1] = "Barrow Centre";\r\n    zonearray[8] [0] = "Lecky";\r\n    zonearray[8] [1] = "Lecky";\r\n    zonearray[9] [0] = "C&J";\r\n    zonearray[9] [1] = "C&J";\r\n    zonearray[10] [0] = "WEX";\r\n    zonearray[10] [1] = "WEX";\r\n    zonearray[11] [0] = "WW";\r\n    zonearray[11] [1] = "WW";\r\n    zonearray.sort();\r\n    if (strZoneOrDept != "DeptIdentifier") {\r\n        cbxFilter.options[0] = new Option("Unfiltered","(None)");\r\n        var j = 1;\r\n    }\r\n    else {\r\n        var j = 0;\r\n    }\r\n    if (strZoneOrDept == "Zone") {\r\n        for (var i = 0; i<zonearray.length; i++) {\r\n            cbxFilter.options[j] = new Option(zonearray[i] [0], zonearray[i] [1]);\r\n            j++;\r\n        }\r\n    }\r\n    else {\r\n        if ((strZoneOrDept == "Dept") || (strZoneOrDept == "DeptIdentifier")) {\r\n            for (var i = 0; i<deptarray.length; i++) {\r\n                if (strZoneOrDept == "Dept") {\r\n                    cbxFilter.options[j] = new Option(deptarray[i] [0], deptarray[i] [1]);\r\n                    j++;\r\n                }\r\n                else {\r\n                    cbxFilter.options[j] = new Option(deptarray[i] [0], deptarray[i] [1]);\r\n                    j++;\r\n                }\r\n            }\r\n        }\r\n     ...

# %%
department = re.findall(r"[a-zA-Z]+array\[0\] \[0\] = \"[a-zA-Z ,&-]+\";", filterJS) # deptarray[0] [0] = "Department of Sports, Media & Marketing"

# %%
department
# Out:
# ['deptarray[0] [0] = "Department of Sports, Media & Marketing";',
#  'zonearray[0] [0] = "Haughton Building";',
#  'staffarray[0] [0] = "REDMOND, FIONA";']

# %%
departments = re.findall(r"[a-zA-Z]+array\[[0-9]\] \[[0-9]\] = \"[a-zA-Z ,&\-\%]+\";", filterJS)

# %%
departments
# Out:
# ['deptarray[0] [0] = "Department of Sports, Media & Marketing";',
#  'deptarray[0] [1] = "SMM";',
#  'deptarray[1] [0] = "Institute of Technology Carlow";',
#  'deptarray[1] [1] = "ITC";',
#  'deptarray[2] [0] = "Department of Lifelong Learning - Carlow";',
#  'deptarray[2] [1] = "NGT";',
#  'deptarray[3] [0] = "Wexford Campus";',
#  'deptarray[3] [1] = "WEX";',
#  'deptarray[4] [0] = "Wexford Campus Lifelong Learning";',
#  'deptarray[4] [1] = "WNT";',
#  'deptarray[5] [0] = "Department of Lifelong Learning - Wicklow";',
#  'deptarray[5] [1] = "WW";',
#  'deptarray[6] [0] = "Department of Business";',
#  'deptarray[6] [1] = "BC";',
#  'deptarray[7] [0] = "Department of Management Studies";',
#  'deptarray[7] [1] = "MS";',
#  'deptarray[8] [0] = "Department of the Built Environment & Extended Campus";',
#  'deptarray[8] [1] = "BE";',
#  'deptarray[9] [0] = "Department of Humanities";',
#  'deptarray[9] [1] = "HM";',
#  'zonearray[0] [0] = "Haughton Building";',
#  'zonearray[0] [1] = "Haughton Building";',
#  'zonearray[1] [0] = "Portarlington";',
#  'zonearray[2] [0] = "CIM";',
#  'zonearray[2] [1] = "CIM";',
#  'zonearray[3] [0] = "LRC";',
#  'zonearray[3] [1] = "LRC";',
#  'zonearray[4] [0] = "Nore Building";',
#  'zonearray[4] [1] = "Nore Building";',
#  'zonearray[5] [0] = "Burrin Building";',
#  'zonearray[5] [1] = "Burrin Building";',
#  'zonearray[6] [0] = "Killeshin Centre";',
#  'zonearray[6] [1] = "Killeshin Centre";',
#  'zonearray[7] [0] = "Barrow Centre";',
#  'zonearray[7] [1] = "Barrow Centre";',
#  'zonearray[8] [0] = "Lecky";',
#  'zonearray[8] [1] = "Lecky";',
#  'zonearray[9] [0] = "C&J";',
#  'zonearray[9] [1] = "C&J";',
#  'modulearray[0] [1] = "WEX";',
#  'modulearray[1] [1] = "DSH";',
#  'modulearray[2] [1] = "DSH";',
#  'modulearray[3] [1] = "SMM";',
#  'modulearray[4] [1] = "DSH";',
#  'modulearray[5] [1] = "WEX";',
#  'modulearray[6] [1] = "WEX";',
#  'modulearray[7] [1] = "WEX";',
#  'modulearray[8] [1] = "DSH";',
#  'modulearray[9] [1] = "DSH";',
#  'modulearray[0] [1] = "WEX";',
#  'modulearray[1] [1] = "DSH";',
#  'modulearray[2] [1] = "DSH";',
#  'modulearray[3] [1] = "SMM";',
#  'modulearray[4] [1] = "DSH";',
#  'modulearray[5] [1] = "WEX";',
#  'modulearray[6] [1] = "WEX";',
#  'modulearray[7] [1] = "WEX";',
#  'modulearray[8] [1] = "DSH";',
#  'modulearray[9] [1] = "DSH";',
#  'studsetarray[0] [1] = "HM";',
#  'studsetarray[1] [1] = "HM";',
#  'studsetarray[2] [1] = "DSH";',
#  'studsetarray[3] [1] = "DSH";',
#  'studsetarray[4] [1] = "CAN";',
#  'studsetarray[5] [1] = "BC";',
#  'studsetarray[6] [1] = "DSH";',
#  'studsetarray[7] [1] = "CAN";',
#  'studsetarray[8] [1] = "EMA";',
#  'studsetarray[9] [1] = "SMM";',
#  'studsetarray[0] [1] = "HM";',
#  'studsetarray[1] [1] = "HM";',
#  'studsetarray[2] [1] = "DSH";',
#  'studsetarray[3] [1] = "DSH";',
#  'studsetarray[4] [0] = "Master of Science in Cyber Security";',
#  'studsetarray[4] [1] = "CAN";',
#  'studsetarray[5] [1] = "BC";',
#  'studsetarray[6] [1] = "DSH";',
#  'studsetarray[7] [1] = "CAN";',
#  'studsetarray[8] [1] = "EMA";',
#  'studsetarray[9] [0] = "Masters of Science in Sports Performance Analysis";',
#  'studsetarray[9] [1] = "SMM";',
#  'roomarray[0] [1] = "WEX";',
#  'roomarray[1] [1] = "Unknown";',
#  'roomarray[2] [1] = "Unknown";',
#  'roomarray[3] [1] = "Unknown";',
#  'roomarray[4] [1] = "Unknown";',
#  'roomarray[5] [1] = "Unknown";',
#  'roomarray[6] [1] = "Unknown";',
#  'roomarray[7] [1] = "Unknown";',
#  'roomarray[8] [1] = "Unknown";',
#  'roomarray[9] [1] = "Unknown";',
#  'roombydeptarray[0] [1] = "WEX";',
#  'roombydeptarray[1] [1] = "BC";',
#  'roombydeptarray[2] [1] = "BC";',
#  'roombydeptarray[3] [1] = "MS";',
#  'roombydeptarray[4] [1] = "NGT";',
#  'roombydeptarray[5] [1] = "NGT";',
#  'roombydeptarray[6] [1] = "NGT";',
#  'roombydeptarray[7] [1] = "DSH";',
#  'roombydeptarray[8] [1] = "DSH";',
#  'roombydeptarray[9] [1] = "CAN";',
#  'progarray[0] [1] = "DSH";',
#  'progarray[1] [1] = "CAN";',
#  'progarray[2] [1] = "BE";',
#  'progarray[3] [1] = "DSH";',
#  'progarray[4] [1] = "SMM";',
#  'progarray[5] [1] = "WEX";',
#  'progarray[6] [1] = "WEX";',
#  'progarray[7] [1] = "NGT";',
#  'progarray[8] [1] = "NGT";',
#  'progarray[9] [1] = "NGT";',
#  'progarray[0] [1] = "DSH";',
#  'progarray[1] [1] = "CAN";',
#  'progarray[2] [1] = "BE";',
#  'progarray[3] [1] = "DSH";',
#  'progarray[4] [1] = "SMM";',
#  'progarray[5] [1] = "WEX";',
#  'progarray[6] [1] = "WEX";',
#  'progarray[7] [1] = "NGT";',
#  'progarray[8] [1] = "NGT";',
#  'progarray[9] [1] = "NGT";',
#  'staffarray[0] [0] = "REDMOND, FIONA";',
#  'staffarray[0] [1] = "CAN";',
#  'staffarray[1] [1] = "CAN";',
#  'staffarray[2] [0] = "BALFE, JOHN";',
#  'staffarray[2] [1] = "WEX";',
#  'staffarray[3] [0] = "EKISA, CONRAD";',
#  'staffarray[3] [1] = "EMA";',
#  'staffarray[4] [0] = "PETERSEN, STEPHAN";',
#  'staffarray[4] [1] = "BE";',
#  'staffarray[5] [0] = "PICOVICI, DOREL";',
#  'staffarray[5] [1] = "EMA";',
#  'staffarray[6] [0] = "CREERY, NIALL";',
#  'staffarray[6] [1] = "EMA";',
#  'staffarray[7] [0] = "BUTLER, RICHARD";',
#  'staffarray[7] [1] = "CAN";',
#  'staffarray[8] [0] = "GRINCELL, MARK";',
#  'staffarray[8] [1] = "BE";',
#  'staffarray[9] [0] = "MC CORMICK, IRENE";',
#  'staffarray[9] [1] = "SMM";']

# %%
department_name = "dept"

# %%
full_department_name = re.findall(rf"{department_name}array\[[0-9]\] \[[0]\] = \"([a-zA-Z ,&\-\%]+)\"", filterJS)

# %%
full_department_name
# Out:
# ['deptarray[0] [0] = "Department of Sports, Media & Marketing";',
#  'deptarray[1] [0] = "Institute of Technology Carlow";',
#  'deptarray[2] [0] = "Department of Lifelong Learning - Carlow";',
#  'deptarray[3] [0] = "Wexford Campus";',
#  'deptarray[4] [0] = "Wexford Campus Lifelong Learning";',
#  'deptarray[5] [0] = "Department of Lifelong Learning - Wicklow";',
#  'deptarray[6] [0] = "Department of Business";',
#  'deptarray[7] [0] = "Department of Management Studies";',
#  'deptarray[8] [0] = "Department of the Built Environment & Extended Campus";',
#  'deptarray[9] [0] = "Department of Humanities";']

# %%
shorten_department_name = re.findall(rf"{department_name}array\[[0-9]\] \[[1]\] = \"([a-zA-Z ,&\-\%]+)\"", filterJS)

# %%
shorten_department_name
# Out:
# ['SMM',
#  'ITC',
#  'NGT',
#  'WEX',
#  'WNT',
#  'WW',
#  'BC',
#  'MS',
#  'BE',
#  'HM',
#  'WEX',
#  'BC',
#  'BC',
#  'MS',
#  'NGT',
#  'NGT',
#  'NGT',
#  'DSH',
#  'DSH',
#  'CAN']
